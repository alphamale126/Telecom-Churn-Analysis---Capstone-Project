# %% [markdown]
# <a href="https://colab.research.google.com/github/alphamale126/Telecom-Churn-Analysis---Capstone-Project/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %% [markdown]
# # **Customer Churn and its Effect on Telecom Industry**

# %% [markdown]
# Customer churn is the percentage of customers that stopped using company's product or service during a certain time frame.
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry as this effects the revenues of the companies.
#
# In this highly competitive market, the average churn rate in telecom businesses is 22%, compared to 19% in IT, and 16% in professional services and it costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become even more important than customer acquisition.
# Therefore, finding those factors that increase customer churn is important to take necessary actions to reduce this churn.
#
# The main goal of our project is to understand the factors for customer churn which assists telecom operators to predict customers who are most likely subject to churn, and what to do to retain the most valuable customer.

# %% [markdown]
# # **The Goal of the project**
#
#
# 1.Finding the factors which are effecting the customers and resulting in customers churn.
#
# 2.To provide appropriate steps for retaining churned customers which inturn increases the companies profits
#
# 3.Providing effective offers to retain most valuable customers and to minimizes the customer churn

# %% [markdown]
# # **Importing Modules and Loading Data**

# %%
#Importing the required packages
import pandas as pd
import numpy as np

#Import visualization packages

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Inserting the data file 
telecom_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Telecom Churn.csv')

# %% [markdown]
# # **Exploring the Data in the given dataset**

# %%
#Data included in the top 5 rows
telecom_df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#Data included in bottom 5 rows
telecom_df.tail(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
# Printing the shape of the dataset
print(telecom_df.shape)
# Out:
# (3333, 20)

# %%
#Printing the attributes
print("Features of the dataset:")
telecom_df.columns
# Out:
# Features of the dataset:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Understanding the datatype of each attribute
telecom_df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
# Checking for Null values
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# From above, we can say that no atrribute consists of any null values

# %%
#Finding the unique values
telecom_df.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
#Analysing both categorical and numerical values in the dataset
telecom_df.describe(include='all')
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   3333     3333.000000  3333.000000               3333            3333
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq     106             NaN          NaN               3010            2411
# mean     NaN      101.064806   437.182418                NaN             NaN
# std      NaN       39.822106    42.371290                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       74.000000   408.000000                NaN             NaN
# 50%      NaN      101.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %% [markdown]
# ## **Looking for Duplicate and Missing values**

# %%
#Count of missing values in each attribute.
telecom_df.isna().sum()
telecom_df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# We can say from the above, that there are no missing values present in any attributes

# %%
#Plotting the missing values
missing_values = pd.DataFrame((telecom_df.isnull().sum())*100/telecom_df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing_values)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Checking for Duplicate Values
len(telecom_df[telecom_df.duplicated()])
# Out:
# 0

# %% [markdown]
# From the above we can say that there are no missing values in any attributes, Hence there is no need to do the missing value imputation,
# we can also observe that there are no duplicate values present in any of the attributes.

# %% [markdown]
# # **Exploratory Data Analysis Of The Data Set**

# %% [markdown]
# **Analyzing the Dependent Variable 'CHURN'**

# %%
#Unique values in "churn" attribute
telecom_df["Churn"].unique()
# Out:
# array([False,  True])

# %%
#Count of the values in 'churn' attribute
print(telecom_df.Churn.value_counts())
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
#Plotting the 'churn' attribute
sns.countplot(x=telecom_df.Churn)

# %%
#Plotting a pie chart to analyze 'churn' attribute
telecom_df ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for Churn')
plt.show()

# %% [markdown]
# After analyzing the churn attribute, we can say that 14.5 percent of customers have churned and 85.5 percent are not churned.

# %% [markdown]
# **Analyzing the state attribute**

# %%
#Unique values of state attribute
telecom_df['State'].nunique()
# Out:
# 51

# %%
#Comparing the Churn attribute with state attribuute using countplot
sns.set(style="darkgrid")
plt.figure(figsize=(25,8))
sc = sns.countplot(x='State', hue="Churn", data=telecom_df)
plt.show()

# %%
#Calculating the State vs Churn percentage
State_data = pd.crosstab(telecom_df["State"],telecom_df["Churn"])
State_data['Percentage_Churn'] = State_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(State_data)
print(len(State_data))
# Out:
# Churn  False  True  Percentage_Churn
# State
# AK        49     3          5.769231
# AL        72     8         10.000000
# AR        44    11         20.000000
# AZ        60     4          6.250000
# CA        25     9         26.470588
# CO        57     9         13.636364
# CT        62    12         16.216216
# DC        49     5          9.259259
# DE        52     9         14.754098
# FL        55     8         12.698413
# GA        46     8         14.814815
# HI        50     3          5.660377
# IA        41     3          6.818182
# ID        64     9         12.328767
# IL        53     5          8.620690
# IN        62     9         12.676056
# KS        57    13         18.571429
# KY        51     8         13.559322
# LA        47     4          7.843137
# MA        54    11         16.923077
# MD        53    17         24.285714
# ME        49    13         20.967742
# MI        57    16         21.917808
# MN        69    15         17.857143
# ...

# %%
#Top 10 States with churn
telecom_df.groupby(['State'])['Churn'].mean().sort_values(ascending = False).head(10)
# Out:
# State
# NJ    0.264706
# CA    0.264706
# TX    0.250000
# MD    0.242857
# SC    0.233333
# MI    0.219178
# MS    0.215385
# NV    0.212121
# WA    0.212121
# ME    0.209677
# Name: Churn, dtype: float64

# %%
#Plotting the churn rate with respect to the state attribute
s1=telecom_df['State'].unique()
s2=telecom_df.groupby(['State'])['Churn'].mean()

plt.rcParams['figure.figsize'] = (18, 7)

plt.plot(s1,s2,color='b', marker='o', linewidth=2, markersize=12)

plt.title(" States churn rate", fontsize = 20)
plt.xlabel('state', fontsize = 15)
plt.ylabel('churn rate', fontsize = 15)
plt.show()

# %%
#Plotting the states with most churn percentage
plt.rcParams['figure.figsize'] = (12, 7)
color = plt.cm.copper(np.linspace(0, 0.5, 20))
((telecom_df.groupby(['State'])['Churn'].mean())*100).sort_values(ascending = False).head(10).plot.bar(color = ['violet','indigo','b','g','y','orange','r'])
plt.title(" State with most churn percentage", fontsize = 20)
plt.xlabel('state', fontsize = 15)
plt.ylabel('percentage', fontsize = 15)
plt.show()

# %% [markdown]
# From the above analysis, we can say that there are 51 unique states with different churn rate and states NJ,CA,TX,MD,SC,MI,MS,NV,WA,ME are the states with high churn rate which is above 20%.
#
# The reason for this churn might be low network coverage or poor signal supply at the respective states.

# %% [markdown]
# **Analyzing the 'Area code' attribute**

# %%
#Area code vs Churn percentage
Area_code_data = pd.crosstab(telecom_df["Area code"],telecom_df["Churn"])
Area_code_data['Percentage_Churn'] = Area_code_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Area_code_data)
# Out:
# Churn      False  True  Percentage_Churn
# Area code
# 408          716   122         14.558473
# 415         1419   236         14.259819
# 510          715   125         14.880952

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x='Area code', hue="Churn", data=telecom_df)
plt.show()

# %% [markdown]
# From the above analysis, we can say that there are 3 unique Area codes i.e, 408, 415, 510 and the churn rate of these area codes are almost the same(14%).
#
# So we can assume that there is no proper relation between the "area code" and"churn" due to which the customer leaves the operator.

# %% [markdown]
# **Analyzing the Account length attribute**

# %%
#Evaluating the churned and not churned customers
churn_df = telecom_df[telecom_df["Churn"] == bool(True)]
cd=len(churn_df)
not_churn_df = telecom_df[telecom_df["Churn"] == bool(False)]
nc=len(not_churn_df)
print(cd, nc)
# Out:
# 483 2850

# %%
#Plot for Account length vs Churn
sns.distplot(telecom_df['Account length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Comparing the churned account length and not churned account length 
sns.distplot(telecom_df['Account length'],color = 'yellow',label="All")
sns.distplot(churn_df['Account length'],color = "red",hist=False,label="Churned")
sns.distplot(not_churn_df['Account length'],color = 'green',hist= False,label="Not churned")
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# From the above analysis, we can say that account length is not implying much effect for the churn of customers

# %% [markdown]
# **Analyzing the 'International Plan' attribute**

# %%
#Finding the number of customers with and without international plan
telecom_df['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
#Unique values of "International plan" attribute
telecom_df["International plan"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#International Plan vs Churn percentage 
International_plan_data = pd.crosstab(telecom_df["International plan"],telecom_df["Churn"])
International_plan_data['Percentage Churn'] = International_plan_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(International_plan_data)
# Out:
# Churn               False  True  Percentage Churn
# International plan
# No                   2664   346         11.495017
# Yes                   186   137         42.414861

# %%
#Pieplot for International plan
telecom_df ['International plan'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for International plan ')
plt.show()

# %%
#Analysing by using countplot
sns.countplot(x='International plan',hue="Churn",data = telecom_df)

# %% [markdown]
# From the above analysis we can say that,
#
# There are 3010 customers i.e, 90.3% with no international plan and
#
# 323 customers i.e, 9.7% with an international plan.
#
# 42.4% customers with an internatinal plan are churned.
#
# 11.4 % customers with no international plan are churned.
#
# Hence we can say that customers with an International plan are being churned.
#
# This might be because of the connectivity issues or high call charges

# %% [markdown]
# **Analyzing the 'Voicemail plan' attribute**

# %%
#Unique values of the "Voice mail plan" attribute
telecom_df["Voice mail plan"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#Voice Mail Plan vs Churn percentage
Voice_mail_plan_data = pd.crosstab(telecom_df["Voice mail plan"],telecom_df["Churn"])
Voice_mail_plan_data['Percentage Churn'] = Voice_mail_plan_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Voice_mail_plan_data)
# Out:
# Churn            False  True  Percentage Churn
# Voice mail plan
# No                2008   403         16.715056
# Yes                842    80          8.676790

# %%
telecom_df ['Voice mail plan'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%',  startangle=90,shadow=True, figsize=(8,8))
plt.title('Pie Chart for Voice mail plan ')
plt.show()

# %%
#Analysing by using countplot
sns.countplot(x='Voice mail plan',hue="Churn",data = telecom_df)

# %% [markdown]
# From the above  analysis we can say that
#
# 2008 i.e, 72.3% customers do not have a Voicemail plan, of which
#
# 403 i.e, 16.7% customers are churned
#
# 842 i.e, 27.7% customers have a Voicemail plan, of which
#
# 80 i.e, 8.6%
# customers are churned
#
# As there is no proper correlation between churn and Voicemail plan, we cannot conclude that this attribute is a reason for the customer churn

# %% [markdown]
# **Analyzing the Number vmail messages attribute**

# %%
#Finding the Unique values in 'Number vmail messages' attribute 
telecom_df['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9])

# %%
#Printing the data of 'Number vmail messages'
telecom_df['Number vmail messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 22      32
# 35      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 50       2
# 9        2
# 8        2
# 11       2
# 48       2
# 49       1
# 4        1
# 10       1
# 51       1
# Name: Number vmail messages, dtype: int64

# %%
#Exploring the data in 'Number vmail messages' attribute
telecom_df['Number vmail messages'].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: Number vmail messages, dtype: float64

# %%
#Boxplot between 'number vmail messages' and 'churn'
fig = plt.figure(figsize =(10, 8)) 
telecom_df.boxplot(column='Number vmail messages', by='Churn')
fig.suptitle('Number vmail message', fontsize=14, fontweight='bold')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#Analysing by using displot diagram
sns.distplot(telecom_df['Number vmail messages'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# From the above analysis on voice mail attribute we can say that when there are more than 20 voice-mail messages there is a churn in customers.
#
# Reason for this churn might be low voice mail quality,
#
# Hence we can say that the quality of the voice mail is to be improved .

# %% [markdown]
# **Analyzing all the calls minutes,all calls, all calls charges attributes together**

# %% [markdown]
# All these attributes are of numerical data type, where as 'churn' is a catagorical data type, so we are going to use mean, median & scatter, box plots.

# %%
#Mean value of churned and not churned customer for Total day calls
print(telecom_df.groupby(["Churn"])['Total day calls'].mean())
# Out:
# Churn
# False    100.283158
# True     101.335404
# Name: Total day calls, dtype: float64

# %%
#Mean value of churned and not churned customer for Total day minutes
print(telecom_df.groupby(["Churn"])['Total day minutes'].mean())
# Out:
# Churn
# False    175.175754
# True     206.914079
# Name: Total day minutes, dtype: float64

# %%
#Mean value of churned and not churned customer for Total day charges 
print(telecom_df.groupby(["Churn"])['Total day charge'].mean())
# Out:
# Churn
# False    29.780421
# True     35.175921
# Name: Total day charge, dtype: float64

# %%
#Plotting the relation using scatter plot
sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", data=telecom_df,palette='hls')

# %%
#Mean value of churned and not churned customer for Total evening calls
print(telecom_df.groupby(["Churn"])['Total eve calls'].mean())
# Out:
# Churn
# False    100.038596
# True     100.561077
# Name: Total eve calls, dtype: float64

# %%
#Mean value of churned and not churned customer for Total evening minutes
print(telecom_df.groupby(["Churn"])['Total eve minutes'].mean())
# Out:
# Churn
# False    199.043298
# True     212.410145
# Name: Total eve minutes, dtype: float64

# %%
#Mean value of churned and not churned customer for Total evening charges
print(telecom_df.groupby(["Churn"])['Total eve charge'].mean())
# Out:
# Churn
# False    16.918909
# True     18.054969
# Name: Total eve charge, dtype: float64

# %%
#Plotting the relation using scatter plot
sns.scatterplot(x="Total eve minutes", y="Total eve charge", hue="Churn", data=telecom_df,palette='hls')

# %%
#Mean value of churned and not churned customer for Total night calls 
print(telecom_df.groupby(["Churn"])['Total night calls'].mean())
# Out:
# Churn
# False    100.058246
# True     100.399586
# Name: Total night calls, dtype: float64

# %%
#Mean value of churned and not churned customer for Total night charges
print(telecom_df.groupby(["Churn"])['Total night charge'].mean())
# Out:
# Churn
# False    9.006074
# True     9.235528
# Name: Total night charge, dtype: float64

# %%
#Mean value of churned and not churned customer for Total night minutes 
print(telecom_df.groupby(["Churn"])['Total night minutes'].mean())
# Out:
# Churn
# False    200.133193
# True     205.231677
# Name: Total night minutes, dtype: float64

# %%
#Plotting the relation using scatter plot
sns.scatterplot(x="Total night minutes", y="Total night charge", hue="Churn", data=telecom_df,palette='hls')

# %%
#Mean value of churned and not churned customer for Total international minutes 
print(telecom_df.groupby(["Churn"])['Total intl minutes'].mean())
# Out:
# Churn
# False    10.158877
# True     10.700000
# Name: Total intl minutes, dtype: float64

# %%
#Mean value of churned and not churned customer for total international calls
print(telecom_df.groupby(["Churn"])['Total intl calls'].mean())
# Out:
# Churn
# False    4.532982
# True     4.163561
# Name: Total intl calls, dtype: float64

# %%
#Mean value of churned and not churned customer for total international charges
print(telecom_df.groupby(["Churn"])['Total intl charge'].mean())
# Out:
# Churn
# False    2.743404
# True     2.889545
# Name: Total intl charge, dtype: float64

# %%
#Plotting the relation using scatter plot
sns.scatterplot(x="Total intl minutes", y="Total intl charge", hue="Churn", data=telecom_df,palette='hls')

# %%
#Deriving a relation between overall call charge and overall call minutes   
day_charge_all = telecom_df['Total day charge'].mean()/telecom_df['Total day minutes'].mean()
eve_charge_all = telecom_df['Total eve charge'].mean()/telecom_df['Total eve minutes'].mean()
night_charge_all = telecom_df['Total night charge'].mean()/telecom_df['Total night minutes'].mean()
int_charge_all= telecom_df['Total intl charge'].mean()/telecom_df['Total intl minutes'].mean()
print([day_charge_all,eve_charge_all,night_charge_all,int_charge_all])
# Out:
# [0.1700030073913066, 0.08500104871485774, 0.04500041448440013, 0.2700500279887098]

# %%
#Plotting the relation using a bar plot
sns.barplot(x=['Day','Evening','Night','International'],y=[day_charge_all,eve_charge_all,night_charge_all,int_charge_all])

# %% [markdown]
# From the above analysis we have can say that total day, total night, total evening minutes/calls/charges are not much of a reason for customer churn.
#
# But international call charges are high when compared to others. From this we can assume that this might have been a cause for international plan customers to churn out.

# %% [markdown]
# **Analyzing the Customer service calls attribute**

# %%
#Data of customer service calls attribute
telecom_df['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
#Customer service calls vs Churn percentage
Customer_service_calls_data = pd.crosstab(telecom_df['Customer service calls'],telecom_df["Churn"])
Customer_service_calls_data['Percentage_Churn'] = Customer_service_calls_data.apply(lambda x : x[1]*100/(x[0]+x[1]),axis = 1)
print(Customer_service_calls_data)
# Out:
# Churn                   False  True  Percentage_Churn
# Customer service calls
# 0                         605    92         13.199426
# 1                        1059   122         10.330229
# 2                         672    87         11.462451
# 3                         385    44         10.256410
# 4                          90    76         45.783133
# 5                          26    40         60.606061
# 6                           8    14         63.636364
# 7                           4     5         55.555556
# 8                           1     1         50.000000
# 9                           0     2        100.000000

# %%
#Analysing using countplot
sns.countplot(x='Customer service calls',hue="Churn",data = telecom_df)

# %% [markdown]
# From the above analysis we can say that, people tend to leave the operator due to the bad customer service.
#
# The above analysis says that customers who called the service center 5 times or more are churned more with a churn percentage higher than 60%,
#
# Customers churn gradually increased with the number of calls, indicating their issue was not solved in the first attempt.
#
# Hence improving the quality of service call is recommended.

# %%
#Plotting the heat map for exploring correlation
plt.figure(figsize=(17,8))
correlation=telecom_df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# **After performing Exploratory Data Analysis on the given data set, we observed the following details that are causing the customer churn:**
#
# 1.There are some states with high churn rate when compared to others, this might be due to the low network coverage over the respective states.
#
# 2.Area code and Account length are not effecting the customers and are not any kind of reason for the customer churn.
#
# 3.Customers with an International plan are tend to be churned more than the customers without an International plan. We also observed that International call charges are high and this reason is also implicting the customers to get churned as they are unsatisfied with the network issue and high call charges
#
# 4.When there are more than 20 voice-mail messages, we observed a churn in customers, From this we can say that the quality of voice mail is not good.
#
# 5.Total day call minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, are not playing any direct role for the customer churn.
#
# 6.International calls data shows that the customers with an International plan have high churn rate, which means that, International call charges are high and also there might be a call drop or network issue regularly.
#
# 7.From the analysis on Customer service calls attribute, we observed that whenever an unsatisfied customer called the service center, there is a churn and this
# customers churn gradually increased with the number of calls, which indicates that their issue was not solved in the first attempt.

# %% [markdown]
# # **Recommendations:**

# %% [markdown]
# 1.Improve the Network coverage and Signal strength in the states with customer churn.
#
# 2.Modify the existing International plan with optimal discounts and improve the network supply, reducing the call drops or signal fluctuations.
#
# 3.Improve the voice mail quality or take feedback from the customer.
#
# 4.Improve the service provided by the call centers and take frequent feedback from the customers regarding their issue.
#
# Try to resolve the issue as soon as possible with good customer satisfaction.
